# %% [markdown]
# # Analisis preeliminar

# %%
import pandas as pd
import pathlib

path = pathlib.Path("../datasets/titanic/titanic3.csv")
df = pd.read_csv(path)

df.head() # leemos los primeros 5 registros
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Dimension del dataset
df.shape # Forma Numero de filas y columnas
# Out:
# (1309, 14)

# %%
df.columns.values # Nombres de las columnas
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %%
# Estadisticas basicas para las variables numericas
# Count: N° de registros no nulos
# Mean: Promedio
# Std: Desviacion estandar
# Min: Valor minimo
# 25%: Primer cuartil
# 50%: Segundo cuartil, mediana
# 75%: Tercer cuartil
# Max: Valor maximo
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# A partir de los estadisticos se puede inferir que 
# No se encontraron todos los cuerpos de los pasajeros

# La edad media de los pasajeros es de 29 años
# La edad minima es de 0.17 años
# La edad maxima es de 80 años
# La mitad de los pasajeros tenian menos de 28 años
# El 75% de los pasajeros tenian menos de 39 años
# Mas de la mitad de los pasajeros murieron
# El 75% de los pasajeros pagaron menos de 31 dolares por el pasaje
# El 25% de los pasajeros pagaron menos de 8 dolares por el pasaje
# Mas del 75% de los pasajeros viajaban en tercera clase
# Mas del 50% de los pasajeros viajaban sin hermanos o conyuges
# Mas del 75% de los pasajeros viajaban sin padres o hijos

# %%
df.dtypes # Tipos de datos de las columnas
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Imputacion de datos faltantes
# Fill na con 0
df2 = df.fillna(0)

# %%
# Sustutir por el promedio
df3 = df

# %%
df3.age = df3.age.fillna(df3.age.mean())
df3.body = df3.body.fillna(df3.body.mean())

# %%
df3
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# 0     female  29.000000      0      0   24160  211.3375       B5        S
# 1       male   0.916700      1      2  113781  151.5500  C22 C26        S
# 2     female   2.000000      1      2  113781  151.5500  C22 C26        S
# 3       male  30.000000      1      2  113781  151.5500  C22 C26        S
# 4     female  25.000000      1      2  113781  151.5500  C22 C26        S
# ...      ...        ...    ...    ...     ...       ...      ...      ...
# 1304  female  14.500000      1      0    2665   14.4542      NaN        C
# 1305  female  29.881135      1      0    2665   14.4542      NaN        C
# 1306    male  26.500000      0      0    2656    7.2250      NaN        C
# 1307    male  27.000000      0      0    2670    7.2250      NaN        C
# 1308    male  29.000000      0      0  315082    7.8750      NaN        S
#
#      boat        body                        home.dest
# 0       2  160.809917                     St Louis, MO
# 1      11  160.809917  Montreal, PQ / Chesterville, ON
# 2     NaN  160.809917  Montreal, PQ / Chesterville, ON
# 3     NaN  135.000000  Montreal, PQ / Chesterville, ON
# 4     NaN  160.809917  Montreal, PQ / Chesterville, ON
# ...   ...         ...                              ...
# 1304  NaN  328.000000                              NaN
# 1305  NaN  160.809917                              NaN
# 1306  NaN  304.000000                              NaN
# 1307  NaN  160.809917                              NaN
# 1308  NaN  160.809917                              NaN
#
# [1309 rows x 14 columns]

# %%
# Dummy variables for sex
df4 = df
df4['sex_male'] = (df4['sex'] == "male").astype(int)
df4['sex_female'] = (df4['sex'] == "female").astype(int)
df4.drop(["sex"] , axis=1, inplace=True)

# %%
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#             age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     29.000000      0      0   24160  211.3375       B5        S    2
# 1      0.916700      1      2  113781  151.5500  C22 C26        S   11
# 2      2.000000      1      2  113781  151.5500  C22 C26        S  NaN
# 3     30.000000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     25.000000      1      2  113781  151.5500  C22 C26        S  NaN
# ...         ...    ...    ...     ...       ...      ...      ...  ...
# 1304  14.500000      1      0    2665   14.4542      NaN        C  NaN
# 1305  29.881135      1      0    2665   14.4542      NaN        C  NaN
# 1306  26.500000      0      0    2656    7.2250      NaN        C  NaN
# 1307  27.000000      0      0    2670    7.2250      NaN        C  NaN
# 1308  29.000000      0      0  315082    7.8750      NaN        S  NaN
#
#             body                        home.dest  sex_male  sex_female
# 0     160.809917                     St Louis, MO         0           1
# 1     160.809917  Montreal, PQ / Chesterville, ON         1           0
# 2     160.809917  Montreal, PQ / Chesterville, ON         0           1
# 3     135.000000  Montreal, PQ / Chesterville, ON         1           0
# 4     160.809917  Montreal, PQ / Chesterville, ON         0           1
# ...          ...                              ...       ...         ...
# 1304  328.000000                              NaN         0           1
# 1305  160.809917                              NaN         0           1
# 1306  304.000000                              NaN         1           0
# 1307  160.809917                              NaN         1           0
# 1308  160.809917                              NaN         1           0
#
# [1309 rows x 15 columns]
